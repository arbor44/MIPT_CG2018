# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from matplotlib.pyplot import imshow
import numpy as np
from sklearn.preprocessing import MinMaxScaler

from utils import task2
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Initialized pictures

# %%
im1 = mpimg.imread('gradient-h.png')
im2 = mpimg.imread('task2.jpg')
im3 = mpimg.imread('lenaTest1.jpg').astype(int)

# %%
plt.figure(figsize=(10, 13))
plt.imshow(im1, cmap='gray')

# %%
plt.figure(figsize=(10, 13))
plt.imshow(im3, cmap='gray')

# %%
plt.figure(figsize=(10, 13))
plt.imshow(im2, cmap='gray')

# %% [markdown]
# # Convert RGB to grayscale

# %%
from utils import convert_to_grayscale

# %%
scaler = MinMaxScaler((0, 255))
im1_gray = convert_to_grayscale(im1, [1/3, 1/3, 1/3])
im1_gray[im1_gray > 1] = 1
im1_gray = im1_gray * 255

# %%
plt.figure(figsize=(10, 13))
plt.imshow(im1_gray, cmap='gray')

# %%
im2_gray = convert_to_grayscale(im2, [0.3, 0.6, 0.1])

# %%
plt.figure(figsize=(10, 13))
plt.imshow(im2_gray, cmap='gray')

# %% [markdown]
# # Gamma correction

# %%
from utils import gamma_correction

# %%
im2_gamma = gamma_correction(im2_gray, 0.5)

# %%
plt.figure(figsize=(10, 13))
plt.imshow(im2_gamma, cmap='gray')

# %% [markdown]
# # Thresholding

# %%
from utils import apply_threshold

# %%
task2(im1_gray, method=apply_threshold, threshold=128)

# %%
task2(im2_gray, method=apply_threshold, threshold=128)

# %%
task2(im3, method=apply_threshold, threshold=128)

# %% [markdown]
# # Random dithering

# %%
task2(im1_gray, method=apply_threshold, threshold=np.random.randint(0, 255, size=im1_gray.shape[:2]))

# %%
task2(im2_gray, method=apply_threshold, threshold=np.random.randint(0, 255, size=im2_gray.shape[:2]))

# %%
task2(im3, method=apply_threshold, threshold=np.random.randint(0, 255, size=im3.shape[:2]))

# %% [markdown]
# # Ordered dithering

# %%
from utils import ordered_threshold

# %%
task2(im1_gray, apply_threshold,
      threshold=np.tile(ordered_threshold(16), im1_gray.shape[:2])[:im1_gray.shape[0], :im1_gray.shape[1]])

# %%
task2(im2_gray, apply_threshold,
      threshold=np.tile(ordered_threshold(16), im2_gray.shape[:2])[:im2_gray.shape[0], :im2_gray.shape[1]])

# %%
task2(im3, apply_threshold,
      threshold=np.tile(ordered_threshold(16), im3.shape[:2])[:im3.shape[0], :im3.shape[1]])

# %% [markdown]
# # Error diffusion forward

# %%
from utils import error1_method

# %%
task2(im1_gray, error1_method, threshold=128)

# %%
task2(im2_gray, error1_method, threshold=128)

# %%
task2(im3, error1_method, threshold=128)

# %% [markdown]
# # Error diffusion backward

# %%
from utils import error2_method

# %%
task2(im1_gray, error2_method, threshold=128)

# %%
task2(im3, error2_method, threshold=128)

# %%
task2(im2_gray, error2_method, threshold=128)

# %% [markdown]
# # Floyd-Steinberg (without raw alternation)

# %%
from utils import FS1_method

# %%
task2(im1_gray, FS1_method, threshold=128)

# %%
task2(im2_gray, FS1_method, threshold=128)

# %%
task2(im3, FS1_method, threshold=128)

# %% [markdown]
# # Floyd-Steinberg (with raw alternation)

# %%
from utils import FS2_method

# %%
task2(im1_gray, FS2_method, threshold=128)

# %%
task2(im2_gray, FS2_method, threshold=128)

# %%
task2(im3, FS2_method, threshold=128)
